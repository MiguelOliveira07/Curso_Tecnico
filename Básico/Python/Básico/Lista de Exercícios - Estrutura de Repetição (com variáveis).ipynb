# %% [markdown]
# # Lista de Exercícios - For (Gabarito)

# %% [markdown]
# #### 1. Faça um Programa que leia as vendas dos vendedores, mostre a venda de cada vendedor com o seu nome e a média de vendas.

# %%
vendas = [1000, 1500, 1200, 1300]
vendedores = ["Fulano", "Beltrano", "Sicrano", "Junin"]

#seu codigo aqui

total = 0

for i, venda in enumerate(vendas):
    print(venda, vendedores[i])
    total += venda
print(total/len(vendas))

# %% [markdown]
# #### 2. Faça um Programa que crie uma lista com as médias de cada aluno, imprima as médias de cada aluno e a quantidade de alunos com média maior que 7.

# %%
alunos = ["José", "Joana", "Maria", "Carla", "Mauricio", "Andre", "Tiago", "Enzo", "Amanda", "Alessandra"]
notas = [
    [10, 9, 8, 8],
    [9, 7, 6, 4],
    [10, 10, 10, 10],
    [5, 3, 10, 9],
    [7, 6, 6, 6],
    [7, 7, 8, 7],
    [7, 7, 7, 9],
    [8, 5, 6, 7],
    [10, 9, 7, 4],
    [10, 1, 3, 3],
]

#seu codigo aqui

contador = 0

for i, nota in enumerate(notas):
    soma = 0
    for elemento in nota:
        soma += elemento
    media = soma / len(nota)
    print(f'Média do aluno {alunos[i]}: {media}')
    
    if media > 7:
        contador += 1

print(f'Alunos com média maior que 7: {contador}')

# %% [markdown]
# #### 3. Foram anotadas as idades e salários de 30 funcionários. Faça um Programa que determine quantos funcionários com mais de 25 anos possuem salário inferior à média de salários desses funcionários.

# %%
idades = [35,32,50,33,48,50,33,48,22,49,35,38,20,47,49,48,34,21,48,44,48,30,25,42,42,23,25,23,38,35]
salarios = [3739,2219,3554,3978,4014,3270,4792,3879,2981,2384,4826,2460,3680,4318,1872,1770,4640,3929,3295,1729,3965,4267,4007,1916,2987,2943,3852,4543,2055,1730]

#seu codigo aqui
media = sum(salarios) / len(salarios)
contador = 0

for i in range(len(idades)):
    if idades[i] > 25 and salarios[i] < media:
        contador += 1 



print(f"Número de funcionários com mais de 25 anos e salário inferior à média: {contador}")

# %% [markdown]
# #### 4.Em quais meses a média de temperatura foi maior do que a média anual?

# %%
meses = [
    'Janeiro',
    'Fevereiro',
    'Março',
    'Abril',
    'Maio',
    'Junho',
    'Julho',
    'Agosto',
    'Setembro',
    'Outubro',
    'Novembro',
    'Dezembro'
]

temperaturas = [30, 29, 28, 28, 25, 26, 20, 21, 19, 25, 27, 32]

#seu codigo aqui
media = sum(temperaturas) / len(temperaturas)
lista = []

for i, mes in enumerate(meses):
    if temperaturas[i] > media:
        lista.append(mes)

print(f'Meses com a média maior que a media anual: {lista}')

# %% [markdown]
# #### 5. As Organizações Tabajara resolveram dar um abono aos seus colaboradores em reconhecimento ao bom resultado alcançado durante o ano que passou. Para isto contratou você para desenvolver a aplicação que servirá como uma projeção de quanto será gasto com o pagamento deste abono.
# <pre>Após reuniões envolvendo a diretoria executiva, a diretoria financeira e os representantes do sindicato laboral, chegou-se a seguinte forma de cálculo:
# . Cada funcionário receberá o equivalente a 20% do seu salário bruto de dezembro;
# . O piso do abono será de 100 reais, isto é, aqueles funcionários cujo salário for muito baixo, recebem este valor mínimo;
#
# Neste momento, não se deve ter nenhuma preocupação com colaboradores com tempo menor de casa, descontos, impostos ou outras particularidades. O programa deverá calcular o valor do abono concedido a cada colaborador, de acordo com a regra definida acima. Ao final, o programa deverá apresentar:</pre>
# <pre>
# O salário de cada funcionário, juntamente com o valor do abono;
# O número total de funcionário processados;
# O valor total a ser gasto com o pagamento do abono;
# O número de funcionário que receberá o valor mínimo de 100 reais;
# O maior valor pago como abono;
# Abaixo segue uma tela de exemplo. A disposição das informações deve ser o mais próxima possível ao exemplo.
# <pre>
# Projeção de Gastos com Abono
# ============================
#
# Salário      Abono
# R$ 1,000.00 - R$  200.00
# R$   300.00 - R$  100.00
# R$   500.00 - R$  100.00
# R$   100.00 - R$  100.00
# R$ 4,500.00 - R$  900.00
#
# Foram processados 5 colaboradores
# Total gasto com abonos: R$ 1,400.00
# Valor mínimo pago a 3 colaboradores
# Maior valor de abono pago: R$ 900.00

# %%
lista_salarios = [1000, 300, 550, 200, 1500, 3000, 3400, 5000, 7000, 2000, 600, 800, 250, 1500, 20000]

#seu codigo aqui
abonos = []
salarios_processados = []

for salario in lista_salarios:
    if (salario * 20) / 100 < 100:
        abono = 100
    else:
        abono = (salario * 20) / 100
    abonos.append(abono)
    salarios_processados.append(salario)
    
print("Projeção de Gastos com Abono")
print("============================")
print("\nSalário      Abono")

for salario, abono in zip(salarios_processados, abonos):
    print(f"R$ {salario:7.2f} - R$ {abono:7.2f}")

total_funcionarios = len(salarios_processados)
total_gasto = sum(abonos)
valor_minimo_pago = sum(1 for abono in abonos if abono == 100)
maior_abono = max(abonos)

print(f"\nForam processados {total_funcionarios} colaboradores")
print(f"Total gasto com abonos: R$ {total_gasto:.2f}")
print(f"Valor mínimo pago a {valor_minimo_pago} colaboradores")
print(f"Maior valor de abono pago: R$ {maior_abono:.2f}")
# Out:
# Projeção de Gastos com Abono
# ...
#
# Salário      Abono
# R$ 1000.00 - R$  200.00
# R$  300.00 - R$  100.00
# R$  550.00 - R$  110.00
# R$  200.00 - R$  100.00
# R$ 1500.00 - R$  300.00
# R$ 3000.00 - R$  600.00
# R$ 3400.00 - R$  680.00
# R$ 5000.00 - R$ 1000.00
# R$ 7000.00 - R$ 1400.00
# R$ 2000.00 - R$  400.00
# R$  600.00 - R$  120.00
# R$  800.00 - R$  160.00
# R$  250.00 - R$  100.00
# R$ 1500.00 - R$  300.00
# R$ 20000.00 - R$ 4000.00
#
# Foram processados 15 colaboradores
# Total gasto com abonos: R$ 9570.00
# Valor mínimo pago a 3 colaboradores
# Maior valor de abono pago: R$ 4000.00

# %% [markdown]
# #### 6. Faça um programa que carregue uma lista com os modelos de cinco carros (exemplo de modelos: FUSCA, GOL, UNO, etc). Carregue uma outra lista com o consumo desses carros, isto é, quantos quilômetros cada um desses carros faz com um litro de combustível. Calcule e mostre:
# <pre>
# a. O modelo do carro mais econômico;
# b. Quantos litros de combustível cada um dos carros cadastrados consome para percorrer uma distância de 1000 quilômetros e quanto isto custará, considerando um que a gasolina custe R$ 2,25 o litro.
# Abaixo segue uma tela de exemplo. A disposição das informações deve ser o mais próxima possível ao exemplo. </pre>
# ```
# Comparativo de Consumo de Combustível
#
# Veículo 1
# Nome: fusca
# Km por litro: 7
#
# Veículo 2
# Nome: gol
# Km por litro: 10
#
# Veículo 3
# Nome: uno
# Km por litro: 12.5
#
# Veículo 4
# Nome: palio
# Km por litro: 9
#
# Veículo 5
# Nome: celta
# Km por litro: 14.5
#
# Relatório Final
# 1 - fusca      -   7.0 - 142.9 litros - R$ 321.43
# 2 - gol        -  10.0 - 100.0 litros - R$ 225.00
# 3 - uno        -  12.5 -  80.0 litros - R$ 180.00
# 4 - palio      -   9.0 - 111.1 litros - R$ 250.00
# 5 - celta      -  14.5 -  69.0 litros - R$ 155.17
#
# O menor consumo é do celta.
# ```

# %%
print('Comparativo de Consumo de Combustível\n')
veiculos = ['fusca','gol', 'uno', 'palio', 'celta']
autonomias = [7, 10, 12.5, 9, 14.5]

#seu codigo aqui

preco_gasolina = 2.25

print('Relatório Final')

menor_consumo = float('inf')
carro_mais_economico = ''

for i in range(len(veiculos)):
    consumo_1000km = 1000 / autonomias[i]
    
    custo_1000km = consumo_1000km * preco_gasolina
    
    print(f'{i+1} - {veiculos[i].ljust(8)} - {str(autonomias[i]).ljust(4)} - {consumo_1000km:.1f} litros - R$ {custo_1000km:.2f}')
    
    if autonomias[i] > menor_consumo:
        menor_consumo = autonomias[i]
        carro_mais_economico = veiculos[i]

print(f'\nO menor consumo é do {carro_mais_economico}.')
# Out:
# Comparativo de Consumo de Combustível
#
# Relatório Final
# 1 - fusca    - 7    - 142.9 litros - R$ 321.43
# 2 - gol      - 10   - 100.0 litros - R$ 225.00
# 3 - uno      - 12.5 - 80.0 litros - R$ 180.00
# 4 - palio    - 9    - 111.1 litros - R$ 250.00
# 5 - celta    - 14.5 - 69.0 litros - R$ 155.17
#
# O menor consumo é do .

# %% [markdown]
# #### 7. Uma empresa paga seus vendedores com base em comissões. O vendedor recebe \\$200 por semana mais 9 por cento de suas vendas brutas daquela semana. Por exemplo, um vendedor que teve vendas brutas de \\$3000 em uma semana recebe \\$200 mais 9 por cento de \\$3000, ou seja, um total de \\$470. Escreva um programa (usando um array de contadores) que determine quantos vendedores receberam salários nos seguintes intervalos de valores:
# <pre>
# $200 - $299
# $300 - $399
# $400 - $499
# $500 - $599
# $600 - $699
# $700 - $799
# $800 - $899
# $900 - $999
# $1000 em diante
# </pre>
#
# Existem várias formas de fazer. Faça primeiro da forma que parecer mais intuitiva para você.
#
# Em seguida, caso queira um desafio:
# Desafio: Crie uma forma para chegar na posição da lista a partir do salário, sem fazer vários ifs aninhados.

# %%
vendas = [1000, 2000, 3000, 4000, 5000, 6000, 5500, 4500, 3600]

#seu codigo aqui
contadores = [0] * 9  
for venda in vendas:
    salario = 200 + 0.09 * venda
    
    indice = min(int((salario - 200) // 100), 8)
    
    contadores[indice] += 1

intervalos = [
    "$200 - $299",
    "$300 - $399",
    "$400 - $499",
    "$500 - $599",
    "$600 - $699",
    "$700 - $799",
    "$800 - $899",
    "$900 - $999",
    "$1000 em diante"
]

for i in range(len(intervalos)):
    print(f"{intervalos[i]}: {contadores[i]} vendedores")
# Out:
# $200 - $299: 1 vendedores
# $300 - $399: 1 vendedores
# $400 - $499: 1 vendedores
# $500 - $599: 2 vendedores
# $600 - $699: 3 vendedores
# $700 - $799: 1 vendedores
# $800 - $899: 0 vendedores
# $900 - $999: 0 vendedores
# $1000 em diante: 0 vendedores
